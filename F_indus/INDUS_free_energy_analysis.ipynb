# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

# %%
with open('/Users/owner/Desktop/EGFR_INDUS_free_energy/indus_results/freeene_wt_active') as f:
    
    lines = f.readlines()
    
    
    
#lines = lines[9:2659]

new_lines = []    
# Get rid of empty lines
for line in lines:
    # Strip whitespace, should leave nothing if empty line was just "\n"
    if not line.strip():
        continue
    # We got something, save it
    else:
        new_lines.append(line)
        
lines = new_lines[0:]
    


y11 = [] # stores the number of water molecules
y21 = [] # stores the free energy values

for i in range(0,len(lines)):
    
    words = lines[i].split()
    int_lst = [float(x) for x in words]
   
    y11.append(int_lst[0]) #y1 takes in the number of water molecules
    y21.append(int_lst[1]) #y2 takes in the free energy
    
 
            
    
y11 = np.array(y11)
y21 = np.array(y21)

# %%
plt.plot(y11,y21)

# %%
with open('/Users/owner/Desktop/EGFR_INDUS_free_energy/indus_results/freeene_l747p_active') as f:
    
    lines = f.readlines()
    
    
    
#lines = lines[9:2659]

new_lines = []    
# Get rid of empty lines
for line in lines:
    # Strip whitespace, should leave nothing if empty line was just "\n"
    if not line.strip():
        continue
    # We got something, save it
    else:
        new_lines.append(line)
        
lines = new_lines[0:]
    


y12 = [] # stores the number of water molecules
y22 = [] # stores the free energy values

for i in range(0,len(lines)):
    
    words = lines[i].split()
    int_lst = [float(x) for x in words]
   
    y12.append(int_lst[0]) #y1 takes in the number of water molecules
    y22.append(int_lst[1]) #y2 takes in the free energy
    
 
            
y12 = np.array(y12)
y22 = np.array(y22)

# %%
with open('/Users/owner/Desktop/EGFR_INDUS_free_energy/indus_results/freeene_d747_753_ins_s_active') as f:
    
    lines = f.readlines()
    
    
    
#lines = lines[9:2659]

new_lines = []    
# Get rid of empty lines
for line in lines:
    # Strip whitespace, should leave nothing if empty line was just "\n"
    if not line.strip():
        continue
    # We got something, save it
    else:
        new_lines.append(line)
        
lines = new_lines[0:]
    


y13 = [] # stores the number of water molecules
y23 = [] # stores the free energy values

for i in range(0,len(lines)):
    
    words = lines[i].split()
    int_lst = [float(x) for x in words]
   
    y13.append(int_lst[0]) #y1 takes in the number of water molecules
    y23.append(int_lst[1]) #y2 takes in the free energy
    
 
            
y13 = np.array(y13)
y23 = np.array(y23)

# %%
with open('/Users/owner/Desktop/EGFR_INDUS_free_energy/indus_results/freeene_d747_750_ins_p_active') as f:
    
    lines = f.readlines()
    
    
    
#lines = lines[9:2659]

new_lines = []    
# Get rid of empty lines
for line in lines:
    # Strip whitespace, should leave nothing if empty line was just "\n"
    if not line.strip():
        continue
    # We got something, save it
    else:
        new_lines.append(line)
        
lines = new_lines[0:]
    


y14 = [] # stores the number of water molecules
y24 = [] # stores the free energy values

for i in range(0,len(lines)):
    
    words = lines[i].split()
    int_lst = [float(x) for x in words]
   
    y14.append(int_lst[0]) #y1 takes in the number of water molecules
    y24.append(int_lst[1]) #y2 takes in the free energy
    
 
            
y14 = np.array(y14)
y24 = np.array(y24)

# %%
with open('/Users/owner/Desktop/EGFR_INDUS_free_energy/indus_results/freeene_d746_750_active') as f:
    
    lines = f.readlines()
    
    
    
#lines = lines[9:2659]

new_lines = []    
# Get rid of empty lines
for line in lines:
    # Strip whitespace, should leave nothing if empty line was just "\n"
    if not line.strip():
        continue
    # We got something, save it
    else:
        new_lines.append(line)
        
lines = new_lines[0:]
    


y15 = [] # stores the number of water molecules
y25 = [] # stores the free energy values

for i in range(0,len(lines)):
    
    words = lines[i].split()
    int_lst = [float(x) for x in words]
   
    y15.append(int_lst[0]) #y1 takes in the number of water molecules
    y25.append(int_lst[1]) #y2 takes in the free energy
    
 
            
y15 = np.array(y15)
y25 = np.array(y25)

# %%
plt.scatter(y11,y21,label='wt', color='red', marker='x')
plt.scatter(y12,y22,label='l747p', color='green', marker='x')
plt.scatter(y13,y23,label='del747_753_ins_s', color='blue', marker='x')
plt.scatter(y14,y24, label='del747_750_ins_p', color='pink', marker='x')
plt.scatter(y15,y25,label='del746_750', color='black', marker='x')
plt.legend()
plt.xlim((1750,2550))
plt.xlabel('No. of water molecules in the probe volume')
plt.ylabel('Free energy in KbT')
plt.savefig('Free_energy.png', bbox_inches = 'tight', dpi = 300)
plt.show()

# %%
## shift the curves and fit to Neq

# %%
wt = y11[(y21 - np.min(y21)).tolist().index(0)]
l747p = y12[(y22 - np.min(y22)).tolist().index(0)]
inS = y13[(y23 - np.min(y23)).tolist().index(0)]
inP = y14[(y24 - np.min(y24)).tolist().index(0)]
del746_750 = y15[(y25 - np.min(y25)).tolist().index(0)]

# %%
wt, l747p, inS, inP, del746_750
# Out:
# (2151.25, 2094.25, 2037.25, 1989.75, 2103.75)

# %%
wt, l747p, inS, inP, del746_750
# Out:
# (2151.25, 2094.25, 2037.25, 1989.75, 2103.75)

# %%
import matplotlib.pyplot as plt
from matplotlib.path import Path
import matplotlib.patches as patches

verts = [
   (-250, 24),  # left, bottom
   (-250, 36),  # left, top
   (-150, 36),  # right, top
   (-150, 24),  # right, bottom
   (0., 0.),  # ignored
]

codes = [
    Path.MOVETO,
    Path.LINETO,
    Path.LINETO,
    Path.LINETO,
    Path.CLOSEPOLY,
]

path = Path(verts, codes)

fig, ax = plt.subplots()
patch1 = patches.PathPatch(path, facecolor='gray', alpha=0.5)


verts = [
   (180, 24),  # left, bottom
   (180, 36),  # left, top
   (350, 36),  # right, top
   (350, 24),  # right, bottom
   (0., 0.),  # ignored
]

codes = [
    Path.MOVETO,
    Path.LINETO,
    Path.LINETO,
    Path.LINETO,
    Path.CLOSEPOLY,
]

path = Path(verts, codes)

fig, ax = plt.subplots()
patch2 = patches.PathPatch(path, facecolor='gray', alpha=0.3)



plt.scatter(y11-y11[(y21 - np.min(y21)).tolist().index(0)],y21 - np.min(y21),label='wt', color='red', marker='x')
plt.scatter(y12-y12[(y22 - np.min(y22)).tolist().index(0)],y22 - np.min(y22),label='l747p', color='green', marker='x')
plt.scatter(y13-y13[(y23 - np.min(y23)).tolist().index(0)],y23 - np.min(y23),label='del747_753_ins_s', color='blue', marker='x')
plt.scatter(y14-y14[(y24 - np.min(y24)).tolist().index(0)],y24 - np.min(y24), label='del747_750_ins_p', color='brown', marker='x')
plt.scatter(y15-y15[(y25 - np.min(y25)).tolist().index(0)],y25 - np.min(y25),label='del746_750', color='black', marker='x')
plt.axhline(y=30, color='gray', linestyle='--', alpha=0.5)
plt.axhline(y=36, color='gray', linestyle='--', alpha=0.5)
plt.axhline(y=24, color='gray', linestyle='--', alpha=0.5)
#ax.add_patch(patch1)
ax.add_patch(patch2)




#plt.axvline(x=-230) # del746_750 left lower
#plt.axvline(x=-180) # del746_750  left upper



#plt.axvline(x=220) # insP right lower
#plt.axvline(x=280) # insP right upper



#plt.axvline(x=-160) # insP left upper 
#plt.axvline(x=-200) # insP left lower




#plt.axvline(x=-180) # insS left upper 
#plt.axvline(x=-220) # insS left lower

#plt.axvline(x=260) # insS right upper 
#plt.axvline(x=340) # insS right lower




#plt.axvline(x=200) # L747P right lower 
#plt.axvline(x=250) # L747P right upper



#plt.axvline(x=-210) # L747P left lower 
#plt.axvline(x=-170) # L747P left upper



#plt.axvline(x=240) # WT right lower 
#plt.axvline(x=310) # WT right upper

#plt.axvline(x=-200) #WT left upper
#plt.axvline(x=-240) #WT left lower

ax.set_xticks([-200,-100,0, 100, 200,300])
ax.set_xticklabels(['Neq-200','Neq-100','Neq','Neq+100', 'Neq+200', 'Neq+300'], rotation=90)


plt.legend(fontsize=7, loc='upper center')
plt.xlim((-260,380))
plt.ylim(0,60)
plt.xlabel('Deviation of no. of water molecules from equilibrium (Neq) in the probe volume')
plt.ylabel('Free energy in kT')
plt.savefig('Free_energy.png', bbox_inches = 'tight', dpi = 300)
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.path import Path
import matplotlib.patches as patches

verts = [
   (-250, 24),  # left, bottom
   (-250, 36),  # left, top
   (-150, 36),  # right, top
   (-150, 24),  # right, bottom
   (0., 0.),  # ignored
]

codes = [
    Path.MOVETO,
    Path.LINETO,
    Path.LINETO,
    Path.LINETO,
    Path.CLOSEPOLY,
]

path = Path(verts, codes)

fig, ax = plt.subplots()
patch1 = patches.PathPatch(path, facecolor='gray', alpha=0.5)


verts = [
   (180, 24),  # left, bottom
   (180, 36),  # left, top
   (350, 36),  # right, top
   (350, 24),  # right, bottom
   (0., 0.),  # ignored
]

codes = [
    Path.MOVETO,
    Path.LINETO,
    Path.LINETO,
    Path.LINETO,
    Path.CLOSEPOLY,
]

path = Path(verts, codes)

fig, ax = plt.subplots()
patch2 = patches.PathPatch(path, facecolor='gray', alpha=0.3)



plt.scatter(y11,y21 - np.min(y21),label='wt', color='red', marker='x')
plt.scatter(y12,y22 - np.min(y22),label='l747p', color='green', marker='x')
plt.scatter(y13,y23 - np.min(y23),label='del747_753_ins_s', color='blue', marker='x')
plt.scatter(y14,y24 - np.min(y24), label='del747_750_ins_p', color='brown', marker='x')
plt.scatter(y15,y25 - np.min(y25),label='del746_750', color='black', marker='x')
plt.axhline(y=30, color='gray', linestyle='--', alpha=0.5)
plt.axhline(y=36, color='gray', linestyle='--', alpha=0.5)
plt.axhline(y=24, color='gray', linestyle='--', alpha=0.5)
ax.add_patch(patch1)
ax.add_patch(patch2)



plt.legend(fontsize=7, loc='upper center')
plt.xlim((1750,2500))
plt.ylim(-30,90)
plt.xlabel('No. of water molecules in the probe volume')
plt.ylabel('Free energy in KbT')
plt.savefig('Free_energy.png', bbox_inches = 'tight', dpi = 300)
plt.show()
