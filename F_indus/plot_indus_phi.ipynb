# %%
import numpy as np
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
# Define the column names
column_names = ['phi', 'beta*phi', '<Nv>_phi', '<delNv^2>', 'dydx']
file_path = 'nt_phi_wt.dat'
df_wt = pd.read_csv(file_path, delim_whitespace=True, skiprows=1, names=column_names)


file_path = 'nt_phi_l747p.dat'
df_l747p = pd.read_csv(file_path, delim_whitespace=True, skiprows=1, names=column_names)



file_path = 'nt_phi_del746_750.dat'
df_746_750 = pd.read_csv(file_path, delim_whitespace=True, skiprows=1, names=column_names)


file_path = 'nt_phi_del747_750_insP.dat'
df_747_750_insP = pd.read_csv(file_path, delim_whitespace=True, skiprows=1, names=column_names)


file_path = 'nt_phi_del747_753_insS.dat'
df_747_753_insS = pd.read_csv(file_path, delim_whitespace=True, skiprows=1, names=column_names)





# Set global font properties
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 22

# Create a subplot with 2 rows and 1 column, sharing the x-axis
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 12), sharex=True)

# Upper plot
ax1.plot(df_wt['beta*phi'], df_wt['<Nv>_phi'] - 2163, linewidth=4, color='red', label='WT')
ax1.plot(df_l747p['beta*phi'], df_l747p['<Nv>_phi'] - 2074, linewidth=4, color='green', label='L747P')
ax1.plot(df_746_750['beta*phi'], df_746_750['<Nv>_phi'] - 2103, linewidth=4, color='black', label='746-750')
ax1.plot(df_747_750_insP['beta*phi'], df_747_750_insP['<Nv>_phi'] - 1967, linewidth=4, color='purple', label='747-750 insP')
ax1.plot(df_747_753_insS['beta*phi'], df_747_753_insS['<Nv>_phi'] - 2030, linewidth=4, color='blue', label='747-753 insS')

# Setting limits
ax1.set_xlim((-0.27, 0))
ax1.set_ylim((0, 800))

# Adding grid
ax1.grid(which='both', linestyle='-.', linewidth=0.5)

# Adding labels
ax1.set_ylabel(r'$<\tilde{N}_{v}>_{\phi} - Neq$', fontsize=22)

# Customize ticks
ax1.tick_params(axis='y', labelsize=23)

# Customize the border
for spine in ax1.spines.values():
    spine.set_edgecolor('black')
    spine.set_linewidth(1.5)

# Bottom plot
# Upper plot
df_wt['<delNv^2>'] = df_wt['<delNv^2>'].apply(pd.to_numeric, errors='coerce')
df_l747p['<delNv^2>'] = df_l747p['<delNv^2>'].apply(pd.to_numeric, errors='coerce')
df_746_750['<delNv^2>'] = df_746_750['<delNv^2>'].apply(pd.to_numeric, errors='coerce')
df_747_750_insP['<delNv^2>'] = df_747_750_insP['<delNv^2>'].apply(pd.to_numeric, errors='coerce')
df_747_753_insS['<delNv^2>'] = df_747_753_insS['<delNv^2>'].apply(pd.to_numeric, errors='coerce')



ax2.plot(df_wt['beta*phi'], df_wt['<delNv^2>'], linewidth=4, color='red', label='WT')
ax2.plot(df_l747p['beta*phi'], df_l747p['<delNv^2>'], linewidth=4, color='green', label='L747P')
ax2.plot(df_746_750['beta*phi'], df_746_750['<delNv^2>'], linewidth=4, color='black', label='746-750')
ax2.plot(df_747_750_insP['beta*phi'], df_747_750_insP['<delNv^2>'], linewidth=4, color='purple', label='747-750 insP')
ax2.plot(df_747_753_insS['beta*phi'], df_747_753_insS['<delNv^2>'], linewidth=4, color='blue', label='747-753 insS')

# Setting limits
#ax2.set_xlim((-0.27, 0))
ax2.set_ylim((0, 19000))

# Adding grid
ax2.grid(which='both', linestyle='-.', linewidth=0.5)

# Adding labels
ax2.set_xlabel(r'$\beta \phi$', fontsize=22)
ax2.set_ylabel(r'$<\delta \tilde{N}_{v}^{2}>_{\phi}$', fontsize=22)

# Customize ticks
ax2.tick_params(axis='x', labelsize=23)
ax2.tick_params(axis='y', labelsize=23)

# Customize the border
for spine in ax2.spines.values():
    spine.set_edgecolor('black')
    spine.set_linewidth(1.5)

# Remove x-ticks from the first plot
ax1.tick_params(axis='x', which='both', bottom=False, top=False)

    
x_pos = -0.08
ymin=0
ymax=0.12
ax1.axvline(x=x_pos, color='#FFAC1E', linewidth=2, linestyle='--', label='Vertical Line', ymin=ymin, ymax=ymax)
ax1.axvline(x=x_pos, color='#FFAC1E', linewidth=8, alpha=0.2, ymin=ymin, ymax=ymax)

x_pos = -0.12
ymin=0
ymax=0.35
ax1.axvline(x=x_pos, color='#FFAC1E', linewidth=2, linestyle='--', label='Vertical Line', ymin=ymin, ymax=ymax)
ax1.axvline(x=x_pos, color='#FFAC1E', linewidth=8, alpha=0.2, ymin=ymin, ymax=ymax)

x_pos = -0.16
ymin=0
ymax=0.68
ax1.axvline(x=x_pos, color='#FFAC1E', linewidth=2, linestyle='--', label='Vertical Line', ymin=ymin, ymax=ymax)
ax1.axvline(x=x_pos, color='#FFAC1E', linewidth=8, alpha=0.2, ymin=ymin, ymax=ymax)



x_pos = -0.08
ymin=0
ymax=1
ax2.axvline(x=x_pos, color='#FFAC1E', linewidth=2, linestyle='--', label='Vertical Line', ymin=ymin, ymax=ymax)
ax2.axvline(x=x_pos, color='#FFAC1E', linewidth=8, alpha=0.2, ymin=ymin, ymax=ymax)

x_pos = -0.12
ymin=0
ymax=1
ax2.axvline(x=x_pos, color='#FFAC1E', linewidth=2, linestyle='--', label='Vertical Line', ymin=ymin, ymax=ymax)
ax2.axvline(x=x_pos, color='#FFAC1E', linewidth=8, alpha=0.2, ymin=ymin, ymax=ymax)

x_pos = -0.16
ymin=0
ymax=1
ax2.axvline(x=x_pos, color='#FFAC1E', linewidth=2, linestyle='--', label='Vertical Line', ymin=ymin, ymax=ymax)
ax2.axvline(x=x_pos, color='#FFAC1E', linewidth=8, alpha=0.2, ymin=ymin, ymax=ymax)



# Remove the last y-tick from the bottom plot
current_yticks = ax2.get_yticks()  # Get current y-ticks
ax2.set_yticks(current_yticks[:-1])  # Set y-ticks excluding the last one

# Adjust layout to prevent overlap
plt.subplots_adjust(hspace=0.0)  # Adjust this value to increase/decrease space between plots

# Save the plot as a high-resolution image
plt.savefig('Indus.png', dpi=600, bbox_inches='tight')

# Show the plot
plt.show()
